# %% [markdown]
# <a href="https://colab.research.google.com/github/Rhezaaa/coursegit/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import json
import pickle
import numpy as np
import tensorflow as tf

import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

intents = json.loads(open('intents.json').read())

words = []
classes = []
documents = []
ignoreLetters = ['?', '!', '.', ',']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        wordList = nltk.word_tokenize(pattern)
        words.extend(wordList)
        documents.append((wordList, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

print(documents)

words = [lemmatizer.lemmatize(word) for word in words if word not in ignoreLetters]
words = sorted(set(words))

classes = sorted(set(classes))

pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

training = []
outputEmpty = [0] * len(classes)

for document in documents:
    bag = []
    wordPatterns = document[0]
    wordPatterns = [lemmatizer.lemmatize(word.lower()) for word in wordPatterns]
    for word in words:
        bag.append(1) if word in wordPatterns else bag.append(0)

    outputRow = list(outputEmpty)
    outputRow[classes.index(document[1])] = 1
    training.append(bag + outputRow)

random.shuffle(training)
training = np.array(training)

trainX = training[:, :len(words)]
trainY = training[:, len(words):]

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(128, input_shape=(len(trainX[0]),), activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(64, activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(len(trainY[0]), activation='softmax'))

sgd = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

model.fit(trainX, trainY, epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5')
print('Done')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [(['hallo'], 'A'), (['hai'], 'A'), (['hey'], 'A'), (['prosedur', 'donor', 'darah'], 'B'), (['bagaimana', 'cara', 'donor', 'darah'], 'B'), (['donor', 'darah'], 'B'), (['cara', 'donor', 'darah'], 'B'), (['prosedur', 'donor', 'darah'], 'B'), (['langkah-langkah', 'donor', 'darah'], 'B'), (['prosedur', 'permintaan', 'darah'], 'C'), (['bagaimana', 'cara', 'minta', 'darah'], 'C'), (['minta', 'darah'], 'C'), (['cara', 'minta', 'darah'], 'C'), (['prosedur', 'permintaan', 'darah'], 'C'), (['langkah-langkah', 'minta', 'darah'], 'C'), (['cara', 'dapat', 'darah'], 'C'), (['Apakah', 'dengan', 'Donor', 'Darah', 'dapat', 'menyehatkan', '?'], 'D'), (['apa', 'donor', 'sehat', '?'], 'D'), (['sehat', 'kah', 'donor', '?'], 'D'), (['Mengapa', 'harus', 'donor', 'darah', '?'], 'E'), (['kenapa', 'harus', 'donor', '?'], 'E'), (['harus', 'donor', '?'], 'E'), (['haruskah', 'donor', 'darah', '?'], 'E'), (['Apa', 'syarat-syarat', 'untuk', 'mendonorkan', 'darah', '?'], 'F'), (['syarat', 'donor'], 'F'), (['apa', 'syarat', 'donor', '?'], 'F'), (['Jangan', 'menyumbangkan', 'darah', 'jika', '?'], 'G'), (['Kapan', 'saat', 'tidak', 'boleh', 'mendonor', 'darah', '?'], 'G'), (['Kapan', 'harus', 'menunda', 'untuk', 'menyumbangkan', 'darah', '?'], 'H'), (['kapan', 'harus', 'menunda', 'donor', '?'], 'H')]
# Epoch 1/200
# 6/6 [==============================] - 1s 7ms/step - loss: 2.0912 - accuracy: 0.1333
# Epoch 2/200
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9815 - accuracy: 0.2000
# Epoch 3/200
# 6/6 [==============================] - 0s 4ms/step - loss: 1.9156 - accuracy: 0.2667
# Epoch 4/200
# 6/6 [==============================] - 0s 4ms/step - loss: 1.9183 - accuracy: 0.3000
# Epoch 5/200
# 6/6 [==============================] - 0s 4ms/step - loss: 1.7835 - accuracy: 0.4000
# Epoch 6/200
# 6/6 [==============================] - 0s 4ms/step - loss: 1.8005 - accuracy: 0.3333
# Epoch 7/200
# 6/6 [==============================] - 0s 4ms/step - loss: 1.6511 - accuracy: 0.4333
# Epoch 8/200
# 6/6 [==============================] - 0s 5ms/step - loss: 1.6176 - accuracy: 0.4667
# Epoch 9/200
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6090 - accuracy: 0.4333
# Epoch 10/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.5445 - accuracy: 0.5333
# Epoch 11/200
# 6/6 [==============================] - 0s 5ms/step - loss: 1.3504 - accuracy: 0.6667
# Epoch 12/200
# 6/6 [==============================] - 0s 4ms/step - loss: 1.2673 - accuracy: 0.5667
# Epoch 13/200
# 6/6 [==============================] - 0s 4ms/step - loss: 1.2073 - accuracy: 0.6000
# Epoch 14/200
# 6/6 [==============================] - 0s 4ms/step - loss: 1.1809 - accuracy: 0.6000
# Epoch 15/200
# 6/6 [==============================] - 0s 5ms/step - loss: 1.1191 - accuracy: 0.6333
# Epoch 16/200
# 6/6 [==============================] - 0s 4ms/step - loss: 1.0644 - accuracy: 0.7333
# Epoch 17/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.9509 - accuracy: 0.6667
# Epoch 18/200
# 6/6 [==============================] - 0s 4ms/step - loss: 1.0382 - accuracy: 0.7667
# Epoch 19/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.8848 - accuracy: 0.7667
# Epoch 20/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.8215 - accuracy: 0.7667
# Epoch 21/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6147 - accuracy: 0.8333
# Epoch 22/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7528 - accuracy: 0.7000
# Epoch 23/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7452 - accuracy: 0.8000
# Epoch 24/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6826 - accuracy: 0.8333
# Epoch 25/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6088 - accuracy: 0.8667
# Epoch 26/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5979 - accuracy: 0.8333
# Epoch 27/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3667 - accuracy: 0.9667
# Epoch 28/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3252 - accuracy: 0.9667
# Epoch 29/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4117 - accuracy: 0.8667
# Epoch 30/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3685 - accuracy: 0.9000
# Epoch 31/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3381 - accuracy: 0.9667
# Epoch 32/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3690 - accuracy: 0.9000
# Epoch 33/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2161 - accuracy: 0.9333
# Epoch 34/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3525 - accuracy: 0.9333
# Epoch 35/200
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3814 - accuracy: 0.9000
# Epoch 36/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2638 - accuracy: 0.9333
# Epoch 37/200
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3138 - accuracy: 0.9000
# Epoch 38/200
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2271 - accuracy: 0.9667
# Epoch 39/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2642 - accuracy: 0.9000
# Epoch 40/200
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1789 - accuracy: 0.9333
# Epoch 41/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2043 - accuracy: 0.9667
# Epoch 42/200
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2034 - accuracy: 0.9333
# Epoch 43/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2126 - accuracy: 0.9333
# Epoch 44/200
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3061 - accuracy: 0.9333
# Epoch 45/200
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2150 - accuracy: 0.9333
# Epoch 46/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1654 - accuracy: 0.9333
# Epoch 47/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2692 - accuracy: 0.9333
# Epoch 48/200
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1655 - accuracy: 0.9667
# Epoch 49/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1606 - accuracy: 1.0000
# Epoch 50/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1640 - accuracy: 0.9333
# Epoch 51/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1692 - accuracy: 0.9667
# Epoch 52/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1767 - accuracy: 0.9333
# Epoch 53/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2203 - accuracy: 0.8667
# Epoch 54/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1824 - accuracy: 0.9000
# Epoch 55/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2214 - accuracy: 0.9667
# Epoch 56/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2841 - accuracy: 0.9000
# Epoch 57/200
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1711 - accuracy: 0.9667
# Epoch 58/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1217 - accuracy: 0.9667
# Epoch 59/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1155 - accuracy: 0.9667
# Epoch 60/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1578 - accuracy: 0.9667
# Epoch 61/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2386 - accuracy: 0.9333
# Epoch 62/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0912 - accuracy: 0.9667
# Epoch 63/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0696 - accuracy: 1.0000
# Epoch 64/200
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1909 - accuracy: 0.9667
# Epoch 65/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2311 - accuracy: 0.9667
# Epoch 66/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1307 - accuracy: 0.9667
# Epoch 67/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1056 - accuracy: 0.9667
# Epoch 68/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0597 - accuracy: 1.0000
# Epoch 69/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2082 - accuracy: 0.9667
# Epoch 70/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0581 - accuracy: 1.0000
# Epoch 71/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0504 - accuracy: 1.0000
# Epoch 72/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0302 - accuracy: 1.0000
# Epoch 73/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0447 - accuracy: 1.0000
# Epoch 74/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0885 - accuracy: 0.9667
# Epoch 75/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1651 - accuracy: 0.9667
# Epoch 76/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0781 - accuracy: 1.0000
# Epoch 77/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0877 - accuracy: 0.9667
# Epoch 78/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0329 - accuracy: 1.0000
# Epoch 79/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0443 - accuracy: 1.0000
# Epoch 80/200
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0614 - accuracy: 1.0000
# Epoch 81/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1943 - accuracy: 0.9667
# Epoch 82/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0522 - accuracy: 1.0000
# Epoch 83/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0369 - accuracy: 1.0000
# Epoch 84/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0830 - accuracy: 1.0000
# Epoch 85/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1653 - accuracy: 0.9333
# Epoch 86/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0468 - accuracy: 1.0000
# Epoch 87/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0521 - accuracy: 1.0000
# Epoch 88/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0624 - accuracy: 1.0000
# Epoch 89/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1464 - accuracy: 0.9667
# Epoch 90/200
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0586 - accuracy: 1.0000
# Epoch 91/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 92/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 93/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2025 - accuracy: 0.9000
# Epoch 94/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1079 - accuracy: 0.9667
# Epoch 95/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1076 - accuracy: 1.0000
# Epoch 96/200
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0856 - accuracy: 0.9667
# Epoch 97/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 98/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0542 - accuracy: 1.0000
# Epoch 99/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 100/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0892 - accuracy: 0.9333
# Epoch 101/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0713 - accuracy: 1.0000
# Epoch 102/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0579 - accuracy: 1.0000
# Epoch 103/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0475 - accuracy: 0.9667
# Epoch 104/200
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0598 - accuracy: 1.0000
# Epoch 105/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 106/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0468 - accuracy: 1.0000
# Epoch 107/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0497 - accuracy: 1.0000
# Epoch 108/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 109/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0399 - accuracy: 1.0000
# Epoch 110/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0806 - accuracy: 1.0000
# Epoch 111/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 112/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0697 - accuracy: 0.9667
# Epoch 113/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 114/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0552 - accuracy: 1.0000
# Epoch 115/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 116/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0663 - accuracy: 1.0000
# Epoch 117/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 118/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0591 - accuracy: 1.0000
# Epoch 119/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 120/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 121/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0508 - accuracy: 1.0000
# Epoch 122/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0336 - accuracy: 1.0000
# Epoch 123/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0605 - accuracy: 1.0000
# Epoch 124/200
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0623 - accuracy: 0.9667
# Epoch 125/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 126/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0930 - accuracy: 0.9667
# Epoch 127/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0485 - accuracy: 1.0000
# Epoch 128/200
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0588 - accuracy: 0.9667
# Epoch 129/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 130/200
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0469 - accuracy: 1.0000
# Epoch 131/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0603 - accuracy: 0.9667
# Epoch 132/200
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 133/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 134/200
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0597 - accuracy: 1.0000
# Epoch 135/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 136/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 137/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0529 - accuracy: 1.0000
# Epoch 138/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 139/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0579 - accuracy: 0.9667
# Epoch 140/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 141/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0723 - accuracy: 1.0000
# Epoch 142/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0606 - accuracy: 0.9667
# Epoch 143/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0337 - accuracy: 1.0000
# Epoch 144/200
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0292 - accuracy: 0.9667
# Epoch 145/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0947 - accuracy: 0.9667
# Epoch 146/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 147/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0337 - accuracy: 1.0000
# Epoch 148/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 149/200
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 150/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 151/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 152/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0651 - accuracy: 0.9667
# Epoch 153/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 154/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1178 - accuracy: 0.9667
# Epoch 155/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 156/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0352 - accuracy: 1.0000
# Epoch 157/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 158/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 159/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 160/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 161/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0432 - accuracy: 0.9667
# Epoch 162/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 163/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0377 - accuracy: 1.0000
# Epoch 164/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0548 - accuracy: 0.9667
# Epoch 165/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0514 - accuracy: 0.9667
# Epoch 166/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 167/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 168/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 169/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 170/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0419 - accuracy: 0.9667
# Epoch 171/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0354 - accuracy: 1.0000
# Epoch 172/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 173/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 174/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1315 - accuracy: 0.9000
# Epoch 175/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0449 - accuracy: 0.9667
# Epoch 176/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 177/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 178/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 179/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0620 - accuracy: 1.0000
# Epoch 180/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 181/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 182/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0639 - accuracy: 0.9667
# Epoch 183/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 184/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0825 - accuracy: 0.9667
# Epoch 185/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0366 - accuracy: 1.0000
# Epoch 186/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0455 - accuracy: 1.0000
# Epoch 187/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0382 - accuracy: 1.0000
# Epoch 188/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 189/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 190/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0278 - accuracy: 1.0000
# Epoch 191/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 192/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0402 - accuracy: 1.0000
# Epoch 193/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 194/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 195/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0769 - accuracy: 0.9667
# Epoch 196/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0267 - accuracy: 1.0000
# Epoch 197/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 198/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 199/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0459 - accuracy: 0.9667
# Epoch 200/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0395 - accuracy: 1.0000
# Done
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import random
import json
import pickle
import numpy as np
import tensorflow as tf

import nltk
from nltk.stem import WordNetLemmatizer

from tensorflow.keras.models import load_model

lemmatizer = WordNetLemmatizer()
intents = json.loads(open('intents.json').read())

words = pickle.load(open('words.pkl', 'rb'))
classes = pickle.load(open('classes.pkl', 'rb'))
model = load_model("chatbot_model.h5")

def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word) for word in sentence_words]
    return sentence_words

def bag_of_words(sentence):
    sentence_words = clean_up_sentence(sentence)
    bag = [0] * len(words)
    for w in sentence_words:
        for i, word in enumerate(words):
            if word == w:
                bag[i] = 1
    return np.array(bag)

def predict_class(sentence):
    bow = bag_of_words(sentence)
    res = model.predict(np.array([bow]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]

    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({'intent': classes[r[0]], 'probability': str(r[1])})
    return return_list

def get_response(intents_list, intents_json):
    tag = intents_list[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if i['tag'] == tag:
            result = random.choice(i['responses'])
            break
    return result

print("HALLO INI CHATBOT")

while True:
    message = input("You: ")

    if message.lower() == 'exit':
        print("Bot: Goodbye!")
        break

    ints = predict_class(message)
    res = get_response(ints, intents)
    print("Bot:", res)
# Out:
# HALLO INI CHATBOT
# You: hai
# 1/1 [==============================] - 0s 103ms/step
# Bot: selamat datang di aplikasi dare 2 donor
# You: bagaimana cara donor darah
# 1/1 [==============================] - 0s 22ms/step
# Bot: Tahap Registrasi : Mengisi formulir pendaftaran dan kuisioner kesehatan
# | Tahap Pemeriksaan Pendahuluan : Pengukuran berat badan, Pemeriksaan kadar haemoglobin darah, Pemeriksaan golongan darah bagi pendonor pemula
# | Tahap Pemeriksaan Kesehatan oleh Dokter : Anamnesis, Pemeriksaan tekanan darah, Pemeriksaan fisik sederhana
# | Tahap Pengambilan Darah Donor : Cuci lengan donor, Pengambilan darah, Pengambilan sampel darah
# | Tahap Administrasi : Mengambil kartu donor dan vitamin
# | Tahap Pemulihan : Pendonor dianjurkan untuk istirahat dan menikmati hidangan ringan yang kami sajikan
# You: exit
# Bot: Goodbye!

# %%
# %shell tensorflowjs_converter --input_format keras /content/chatbot_model.h5 /content/tfjs_model
# Out:
# 2023-12-13 15:39:53.358296: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-13 15:39:53.358385: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-13 15:39:53.359975: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-13 15:39:54.897125: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
